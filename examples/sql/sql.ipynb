# %%
from functools import cache
from pathlib import Path

import chrysalis as chry
import duckdb
import polars as pl
from itables import show

import transformations as transformations
import invariants as invariants

# %%
@cache
def _test_connection() -> duckdb.DuckDBPyConnection:
    input_data_path = Path("./player_stats.parquet")
    if not input_data_path.exists():
        raise RuntimeError("Input dataset does not exist, exiting.")

    conn = duckdb.connect()
    conn.register(
        "player_stats",
        pl.read_parquet(input_data_path).cast({"round": pl.Int8}),
    )
    return conn


def evaluate_query(query: str) -> pl.DataFrame:
    conn = _test_connection()
    return conn.query(query).pl()


_TEST_QUERY = "SELECT name, position, college, team, round, draft FROM player_stats;"

# %%
chry.register(transformations.add_college_column, invariants.length_equals)
chry.register(transformations.add_team_column, invariants.length_equals)
chry.register(transformations.add_round_column, invariants.length_equals)
chry.register(transformations.add_draft_column, invariants.length_equals)
chry.register(transformations.remove_college_column, invariants.length_equals)
chry.register(transformations.remove_team_column, invariants.length_equals)
chry.register(transformations.remove_round_column, invariants.length_equals)
chry.register(transformations.remove_draft_column, invariants.length_equals)

chry.register(transformations.add_order_by_asc, invariants.length_equals)
chry.register(transformations.add_order_by_desc, invariants.length_equals)
chry.register(transformations.remove_order_by, invariants.length_equals)

# Intentional bug, it is possible that adding `LIMIT 400` will remove `LIMIT 200`
# and cause the invariant to fail.
chry.register(transformations.add_limit_400, invariants.length_less_than_equals)
chry.register(transformations.add_limit_200, invariants.length_less_than_equals)
chry.register(transformations.remove_limit, invariants.length_greater_than_equals)

# %%
conn = chry.run(evaluate_query, [_TEST_QUERY], chain_length=50, num_chains=10)

# %%
show(conn.query("SELECT COUNT(*) AS count FROM applied_transformation;").pl())
# Out:
# <table id="itables_6654134c_c60a_4079_aa77_0defce3b1c55" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>count</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.3.0 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_6654134c_c60a_4079_aa77_0defce3b1c55:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [[500]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
chain_start_ids = conn.query("""SELECT id FROM applied_transformation WHERE previous_applied_transformation IS NULL;""").pl()
show(chain_start_ids)
# Out:
# <table id="itables_f34a5eca_dc6d_4e10_9557_08fac5b8e5f3" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>id</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.3.0 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_f34a5eca_dc6d_4e10_9557_08fac5b8e5f3:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["54933b2101a34d09b31140c98c8d7511"], ["e1d7e42c2aec4e0cb64fe2493afab16a"], ["5894d8eee8c2474680ea61cf35409705"], ["c7a1d6aa7cb54bc9a5a5a055132afd40"], ["53c41b4a1a9d43fba51e7cf154fbb1c4"], ["168d3eb6e26c4b46a4d3f00a9adbc226"], ["724d6cea4ad54f6fbef1c1023982ad10"], ["c10b5165217f4e98a2ea8a757b932543"], ["0bd3a3e59d084ec0a8c62c716461260d"], ["9a066595e43e4deca28bb554c93ffaf3"]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
relation_chain = conn.execute("""
WITH RECURSIVE transformation_chain AS (
    SELECT 
        id,
        transformation,
        previous_applied_transformation,
        link_index,
        created_at
    FROM applied_transformation
    WHERE id = ?

    UNION ALL

    SELECT 
        at.id,
        at.transformation,
        at.previous_applied_transformation,
        at.link_index,
        at.created_at
    FROM applied_transformation at
    JOIN transformation_chain tc ON tc.id = at.previous_applied_transformation
)
SELECT tc.link_index, t.name, t.id FROM transformation_chain tc
INNER JOIN transformation t ON tc.transformation = t.id
ORDER BY link_index;
""", (chain_start_ids[1]["id"].item(),)).pl()
show(relation_chain)
# Out:
# <table id="itables_2e92fef6_bb91_4833_a1af_d0529ddf7ed4" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>link_index</th>
#       <th>name</th>
#       <th>id</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.3.0 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_2e92fef6_bb91_4833_a1af_d0529ddf7ed4:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [[0, "add_team_column", "d786e85380b84e699ab5245d9e08a15e"], [1, "add_limit_200", "57078b69c0c54d918ccbf50fabcdfb13"], [2, "add_college_column", "9d01bbf13f4b419499012a73364cb7f1"], [3, "add_college_column", "9d01bbf13f4b419499012a73364cb7f1"], [4, "remove_team_column", "03dd0cc784b641f781ee2ccbffe72359"], [5, "add_draft_column", "a5760107248c4a629791bca42d1855a0"], [6, "remove_limit", "c4fcdc0107b04a44abce28d01c4784df"], [7, "add_order_by_desc", "ac03fdd713c146c496f842e685150416"], [8, "add_limit_200", "57078b69c0c54d918ccbf50fabcdfb13"], [9, "add_team_column", "d786e85380b84e699ab5245d9e08a15e"], [10, "add_team_column", "d786e85380b84e699ab5245d9e08a15e"], [11, "remove_team_column", "03dd0cc784b641f781ee2ccbffe72359"], [12, "add_limit_400", "6c898610884441ff9d8853c27baf05f5"], [13, "add_draft_column", "a5760107248c4a629791bca42d1855a0"], [14, "remove_round_column", "d6bb9d89ef7342d6be46a405fa7d090d"], [15, "remove_order_by", "24cf70ead0964a11a1efb0b99e1b0c9e"], [16, "remove_college_column", "755e7d74fcec48b3bdb0b45ee8f3cc73"], [17, "add_round_column", "4b1b5b44b4cf4950a0620a7051891869"], [18, "add_draft_column", "a5760107248c4a629791bca42d1855a0"], [19, "remove_college_column", "755e7d74fcec48b3bdb0b45ee8f3cc73"], [20, "add_order_by_desc", "ac03fdd713c146c496f842e685150416"], [21, "add_order_by_desc", "ac03fdd713c146c496f842e685150416"], [22, "add_draft_column", "a5760107248c4a629791bca42d1855a0"], [23, "add_college_column", "9d01bbf13f4b419499012a73364cb7f1"], [24, "remove_college_column", "755e7d74fcec48b3bdb0b45ee8f3cc73"], [25, "remove_order_by", "24cf70ead0964a11a1efb0b99e1b0c9e"], [26, "remove_draft_column", "315bc66096034714b2fba1be6669010e"], [27, "add_draft_column", "a5760107248c4a629791bca42d1855a0"], [28, "add_order_by_asc", "811cd4e70c17417594b38324cad21c8a"], [29, "remove_order_by", "24cf70ead0964a11a1efb0b99e1b0c9e"], [30, "remove_college_column", "755e7d74fcec48b3bdb0b45ee8f3cc73"], [31, "remove_round_column", "d6bb9d89ef7342d6be46a405fa7d090d"], [32, "remove_limit", "c4fcdc0107b04a44abce28d01c4784df"], [33, "remove_round_column", "d6bb9d89ef7342d6be46a405fa7d090d"], [34, "remove_order_by", "24cf70ead0964a11a1efb0b99e1b0c9e"], [35, "remove_limit", "c4fcdc0107b04a44abce28d01c4784df"], [36, "remove_draft_column", "315bc66096034714b2fba1be6669010e"], [37, "remove_order_by", "24cf70ead0964a11a1efb0b99e1b0c9e"], [38, "add_limit_200", "57078b69c0c54d918ccbf50fabcdfb13"], [39, "add_order_by_asc", "811cd4e70c17417594b38324cad21c8a"], [40, "remove_round_column", "d6bb9d89ef7342d6be46a405fa7d090d"], [41, "add_order_by_asc", "811cd4e70c17417594b38324cad21c8a"], [42, "add_draft_column", "a5760107248c4a629791bca42d1855a0"], [43, "add_limit_200", "57078b69c0c54d918ccbf50fabcdfb13"], [44, "add_draft_column", "a5760107248c4a629791bca42d1855a0"], [45, "add_draft_column", "a5760107248c4a629791bca42d1855a0"], [46, "remove_draft_column", "315bc66096034714b2fba1be6669010e"], [47, "remove_round_column", "d6bb9d89ef7342d6be46a405fa7d090d"], [48, "add_limit_200", "57078b69c0c54d918ccbf50fabcdfb13"], [49, "add_limit_200", "57078b69c0c54d918ccbf50fabcdfb13"]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
query = _TEST_QUERY
knowledge_base = chry._internal._controller._CURRENT_KNOWLEDGE_BASE

print(f"{'start':<30} {query}")
for (_, name, transform_id) in relation_chain.head(10).iter_rows():
    query = knowledge_base.relations[transform_id].apply_transform(query)
    print(f"{name:<30} {query}")
# Out:
# start                          SELECT name, position, college, team, round, draft FROM player_stats;
# add_team_column                SELECT name, position, college, round, draft, team FROM player_stats
# add_limit_200                  SELECT name, position, college, round, draft, team FROM player_stats LIMIT 200
# add_college_column             SELECT name, position, round, draft, team, college FROM player_stats LIMIT 200
# add_college_column             SELECT name, position, round, draft, team, college FROM player_stats LIMIT 200
# remove_team_column             SELECT name, position, round, draft, college FROM player_stats LIMIT 200
# add_draft_column               SELECT name, position, round, college, draft FROM player_stats LIMIT 200
# remove_limit                   SELECT name, position, round, college, draft FROM player_stats
# add_order_by_desc              SELECT name, position, round, college, draft FROM player_stats ORDER BY draft DESC, round DESC
# add_limit_200                  SELECT name, position, round, college, draft FROM player_stats ORDER BY draft DESC, round DESC LIMIT 200
# add_team_column                SELECT name, position, round, college, draft, team FROM player_stats ORDER BY draft DESC, round DESC LIMIT 200

# %%
show(conn.query("""
SELECT DISTINCT name FROM failed_invariant
INNER JOIN applied_transformation ON failed_invariant.applied_transformation = applied_transformation.id
INNER JOIN transformation ON applied_transformation.transformation = transformation.id
""").pl())
# Out:
# <table id="itables_ceb8a27a_0ebd_47c8_a8fc_b9e14bdf3e22" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>name</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.3.0 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ceb8a27a_0ebd_47c8_a8fc_b9e14bdf3e22:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["remove_limit"], ["add_limit_400"]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
